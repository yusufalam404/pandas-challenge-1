# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Resources/client_dataset.csv')
df.head(20)
# Out:
#         first      last                                           job  \
# 0      Donald   Harding                                  Immunologist
# 1     Tiffany     Myers                               Music therapist
# 2     Shannon    Watson                                  Immunologist
# 3      Nathan     Baker                         Accounting technician
# 4   Christina  Schwartz                                  Chiropractor
# 5     Jessica     Reyes  Production designer, theatre/television/film
# 6       Brian     Moore                                       Barista
# 7       Jesus    Wright                            Theme park manager
# 8     Rebecca     Brown                                   Chiropodist
# 9        Greg    Garcia                            Secretary, company
# 10       Kyle  Williams           Engineer, broadcasting (operations)
# 11    Roberto    Howard                      Surveyor, land/geomatics
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.

# %%
# What three item categories had the most entries?
top_3_categories = df['category'].value_counts().head(3)
top_3_categories = pd.DataFrame(top_3_categories)
top_3_categories
# Out:
#              count
# category
# consumables  23538
# furniture    11915
# software      8400

# %%
# For the category with the most entries, which subcategory had the most entries?

top_subcategory = df['subcategory'].value_counts().head(1)
top_subcategory = pd.DataFrame(top_subcategory)
top_subcategory
# Out:
#                    count
# subcategory
# bathroom supplies   6424

# %%
# Which five clients had the most entries in the data?
#client_df = df['client_id'].value_counts().head(5)

client_df = df['client_id'].value_counts().head(5)
client_df
# client_df = pd.DataFrame(client_df)
# client_df
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
top_5_clients = df['client_id'].value_counts().head(5).index.tolist()
print(top_5_clients)
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
filtered_df = df[df['client_id'] == 33615]
top_qty = filtered_df['qty'].sum()
top_qty
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df['line_subtotal'] = df['unit_price'] * df['qty']
df[['unit_price' , 'qty' , 'line_subtotal']].head(2)
# Out:
#    unit_price  qty  line_subtotal
# 0     1096.80  105      115164.00
# 1       24.95   21         523.95

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
# total_df = df [['unit_price' , 'qty']].copy()
# total_df['line_subtotal'] = total_df['unit_price'] * total_df['qty']
# total_df.head(2)

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
df['total_weight'] = df['unit_weight'] * df['qty']
#if the total weight is > 50 pounds then price = $7, else < 50 pounds then price >= $10
#check np.where documentation
df['price'] = np.where(df['total_weight'] > 50, 7, 10)
df['shipping_price'] = df['total_weight'] * df['price']
df[['unit_price' , 'unit_weight' , 'qty' , 'total_weight' , 'shipping_price']].head()
# print(df.columns)
df = df.drop(columns='price')
# df.columns
# Out:
#    unit_price  unit_weight  qty  total_weight  shipping_price
# 0     1096.80         7.50  105        787.50         5512.50
# 1       24.95         1.49   21         31.29          312.90
# 2       13.52         1.68   39         65.52          458.64
# 3       36.42         1.23   29         35.67          356.70
# 4      195.10        46.43   20        928.60         6500.20

# %%
df = df.drop(columns='price')

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
sales_tax_rate = 1.0925
df['line_price'] = (df['line_subtotal'] + df['shipping_price']) * (sales_tax_rate)
df['line_price'] = df['line_price'].round(2)
df[['line_subtotal' , 'shipping_price' , 'line_price']].head(3)

# # Add a new column for total_price
# sales_tax_rate = 0.0925
# df['total_price'] = (df['shipping_price'] + df['line_subtotal'] * (1 + sales_tax_rate))

# print(df)
# Out:
#    line_subtotal  shipping_price  line_price
# 0      115164.00         5512.50   131839.08
# 1         523.95          312.90      914.26
# 2         527.28          458.64     1077.12

# %%
# df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']
# df.head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# 0          17        2023  ...    1096.80    762.71        7.50  105
# 1          20        2023  ...      24.95     15.09        1.49   21
# 2           4        2023  ...      13.52      7.86        1.68   39
#
#    line_number  line_subtotal  total_weight  shipping_price  line_price  \
# 0            1      115164.00        787.50         5512.50   131839.08
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).

df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']
df.head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# 0          17        2023  ...    1096.80    762.71        7.50  105
# 1          20        2023  ...      24.95     15.09        1.49   21
# 2           4        2023  ...      13.52      7.86        1.68   39
#
#    line_number  line_subtotal  total_weight  shipping_price  line_price  \
# 0            1      115164.00        787.50         5512.50   131839.08
# ...

# %%
# Create a column for the profit of each line using line cost and line price
df['line_profit'] = df['line_price'] - df['line_cost']
df.head(3)
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ... unit_cost unit_weight  qty  line_number  \
# 0          17        2023  ...    762.71        7.50  105            1
# 1          20        2023  ...     15.09        1.49   21            0
# 2           4        2023  ...      7.86        1.68   39            6
#
#    line_subtotal  total_weight  shipping_price  line_price  line_cost  \
# 0      115164.00        787.50         5512.50   131839.08   85597.05
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
# put order ids in a list
client_order_ids = [2742071, 2173913, 6128929]

#define a function
def get_order_total(order_id):
    new_df = df.loc[df['order_id'] == order_id, 'line_price']
    return round(new_df.sum(), 2)

for order_id in client_order_ids:
    print(f"Order {order_id} total: $ {get_order_total(order_id)}")
# Out:
# Order 2742071 total: $ 152811.89
# Order 2173913 total: $ 162388.71
# Order 6128929 total: $ 923441.25

# %%
# Check your work using the totals above
# put order ids in a list

#define a function
# Out:
# Order 2742071 total: $152811.89
# Order 2173913 total: $162388.71
# Order 6128929 total: $923441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
df1 = df[df['client_id'].isin(top_5_clients)]
df1.head()
# Out:
#        first     last                                           job  \
# 5    Jessica    Reyes  Production designer, theatre/television/film
# 12   Jessica    Reyes  Production designer, theatre/television/film
# 137    Bryan    Myers                                Chief of Staff
# 214    Bryan    Myers                                Chief of Staff
# 216   Angela  Everett                                     Osteopath
#
#                 phone                     email  client_id  order_id  \
# 5          5016915923  jessica.reyes@grimes.net      33615   1327730
# 12         5016915923  jessica.reyes@grimes.net      33615   6059361
# 137  444.233.9146x233     bmyers3696@wilson.com      46820   7109502
# 214  444.233.9146x233     bmyers3696@wilson.com      46820   8967498
# 216  729-620-6192x875    aeverett@rodriguez.com      66037   1203693
#
#      order_date  order_week  order_year  ... unit_cost unit_weight  qty  \
# ...

# %%
df2 = df1.groupby('client_id')[['line_price']].sum().reset_index()
df2
# Out:
#    client_id   line_price
# 0      24741  82268892.02
# 1      33615   8377308.52
# 2      38378  12906550.87
# 3      46820   9743794.36
# 4      66037  10259514.79

# %%
df2['formatted_output'] = df2.apply(
lambda row: f"client_id {row['client_id']}: {row['line_price']}", axis=1)

# %%
formatted_outputs = df2['formatted_output'].tolist()
for output in formatted_outputs:
    print(output)
# Out:
# client_id 24741: 82268892.02
# client_id 33615: 8377308.52
# client_id 38378: 12906550.870000001
# client_id 46820: 9743794.36
# client_id 66037: 10259514.790000001

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
# Out:
# 33615: $8377308.52
# 66037: $10259514.79
# 46820: $9743794.36
# 38378: $12906550.87
# 24741: $82268892.02

# %%
df2.head()
# Out:
#    client_id   line_price                     formatted_output
# 0      24741  82268892.02         client_id 24741: 82268892.02
# 1      33615   8377308.52          client_id 33615: 8377308.52
# 2      38378  12906550.87  client_id 38378: 12906550.870000001
# 3      46820   9743794.36          client_id 46820: 9743794.36
# 4      66037  10259514.79  client_id 66037: 10259514.790000001

# %%
top_5_summary_df = df[df['client_id'].isin(top_5_clients)]
top_5_summary_df
# Out:
#            first     last                                           job  \
# 5        Jessica    Reyes  Production designer, theatre/television/film
# 12       Jessica    Reyes  Production designer, theatre/television/film
# 137        Bryan    Myers                                Chief of Staff
# 214        Bryan    Myers                                Chief of Staff
# 216       Angela  Everett                                     Osteopath
# ...          ...      ...                                           ...
# 54535     Angela  Everett                                     Osteopath
# 54536     Kendra  Garrett                        Pension scheme manager
# 54579  Alexandra    Young                                     Dietitian
# 54589  Alexandra    Young                                     Dietitian
# 54613     Kendra  Garrett                        Pension scheme manager
#
#                   phone                            email  client_id  order_id  \
# ...

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 

top_client_summary_df = top_5_summary_df.groupby('client_id').agg({
    'qty': 'sum',
    'shipping_price': 'sum',
    'line_price': 'sum',
    'line_cost' : 'sum',
    'line_profit' : 'sum'
})

top_client_summary_df
# Out:
#               qty  shipping_price   line_price    line_cost  line_profit
# client_id
# 24741      239862      5126448.37  82268892.02  45688899.71  36579992.31
# 33615       64313      1828984.89   8377308.52   6175313.91   2201994.61
# 38378       73667      3429455.40  12906550.87   9634720.98   3271829.89
# 46820       75768      1601448.84   9743794.36   7007191.64   2736602.72
# 66037       43018      1395151.85  10259514.79   7004482.98   3255031.81

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 

 #DONE
# Out:
#    client_id     qty  shipping_price   line_price    line_cost  line_profit
# 0      33615   64313      1828984.89   8377308.52   6175313.91   2201994.61
# 1      66037   43018      1395151.85  10259514.79   7004482.98   3255031.81
# 2      46820   75768      1601448.84   9743794.36   7007191.64   2736602.72
# 3      38378   73667      3429455.40  12906550.87   9634720.98   3271829.89
# 4      24741  239862      5126448.37  82268892.02  45688899.71  36579992.31

# %%
top_client_summary_df = top_client_summary_df.reset_index()
top_client_summary_df
# Out:
#    client_id     qty  shipping_price   line_price    line_cost  line_profit
# 0      24741  239862      5126448.37  82268892.02  45688899.71  36579992.31
# 1      33615   64313      1828984.89   8377308.52   6175313.91   2201994.61
# 2      38378   73667      3429455.40  12906550.87   9634720.98   3271829.89
# 3      46820   75768      1601448.84   9743794.36   7007191.64   2736602.72
# 4      66037   43018      1395151.85  10259514.79   7004482.98   3255031.81

# %%
# Format the data and rename the columns to names suitable for presentation.

top_client_summary_df = top_client_summary_df.rename(columns = {
    'client_id' : 'Client ID' , 
    'qty' : 'Units' , 
    'shipping_price' : 'Shipping (millions)' , 
    'line_price' : 'Total Revenue (millions)',
    'line_cost' : 'Total Cost (millions)' ,
    'line_profit' : 'Total Profit (millions)'
})

top_client_summary_df

# # Define the money columns. 
def currency_format_millions(amount):
    return (amount/1000000)


# # Define a function that converts a dollar amount to millions.
columns_to_convert = ['Shipping (millions)' , 'Total Revenue (millions)', 'Total Cost (millions)', 'Total Profit (millions)']
top_client_summary_df[columns_to_convert] = top_client_summary_df[columns_to_convert].apply(currency_format_millions)
top_client_summary_df

# Apply the currency_format_millions function to only the money columns. 


# Rename the columns to reflect the change in the money format.
# Out:
#    Client ID   Units  Shipping (millions)  Total Revenue (millions)  \
# 0      24741  239862             5.126448                 82.268892
# 1      33615   64313             1.828985                  8.377309
# 2      38378   73667             3.429455                 12.906551
# 3      46820   75768             1.601449                  9.743794
# 4      66037   43018             1.395152                 10.259515
#
#    Total Cost (millions)  Total Profit (millions)
# 0              45.688900                36.579992
# 1               6.175314                 2.201995
# 2               9.634721                 3.271830
# 3               7.007192                 2.736603
# 4               7.004483                 3.255032

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
final_client_summary_df = top_client_summary_df.sort_values(by= 'Total Profit (millions)', ascending = False)
final_client_summary_df
# Out:
#    Client ID   Units  Shipping (millions)  Total Revenue (millions)  \
# 0      24741  239862             5.126448                 82.268892
# 2      38378   73667             3.429455                 12.906551
# 4      66037   43018             1.395152                 10.259515
# 3      46820   75768             1.601449                  9.743794
# 1      33615   64313             1.828985                  8.377309
#
#    Total Cost (millions)  Total Profit (millions)
# 0              45.688900                36.579992
# 2               9.634721                 3.271830
# 4               7.004483                 3.255032
# 3               7.007192                 2.736603
# 1               6.175314                 2.201995
